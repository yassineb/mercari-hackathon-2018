# %%
from google_images_download import google_images_download

# %%
response = google_images_download.googleimagesdownload()   #class instantiation

# %%
arguments = {"output_directory":"category_dataset", "keywords":"T-shirt","limit":100,"print_urls":True}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)
# Out:
# Item no.: 1 --> Item name = T-shirt
# Evaluating...
# Starting Download...
# Image URL: https://mosaic04.ztat.net/vgs/media/pdp-gallery/TO/18/4A/00/HC/11/TO184A00H-C11@9.jpg
# Completed Image ====> 1. to184a00h-c11@9.jpg
# Image URL: https://mosaic03.ztat.net/vgs/media/packshot/pdp-gallery/PO/22/4G/05/FA/11/PO224G05F-A11@16.jpg
# Completed Image ====> 2. po224g05f-a11@16.jpg
# Image URL: https://3.allegroimg.com/s512/03c099/ba4f1d7b4ac8ac3791489e7b6103
# Completed Image ====> 3. ba4f1d7b4ac8ac3791489e7b6103.jpg
# Image URL: https://shirtsofcotton.com/en/media/catalog/product/cache/10/image/1200x1200/9df78eab33525d08d6e5fb8d27136e95/s/h/shirtsofcotton-t-shirt-soc-08-front-1200px.jpg
# Completed Image ====> 4. shirtsofcotton-t-shirt-soc-08-front-1200px.jpg
# Image URL: https://www.montane.co.uk/images/dart-t-shirt-p671-14248_image.jpg
# Completed Image ====> 5. dart-t-shirt-p671-14248_image.jpg
# Image URL: https://takierzeczy.com/wp-content/uploads/2017/11/39.jpg
# ...

# %%
arguments = {"output_directory":"category_dataset", "keywords":"pants","limit":100,"print_urls":True}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
# Out:
# Item no.: 1 --> Item name = pants
# Evaluating...
# Starting Download...
# Image URL: https://images.thenorthface.com/is/image/TheNorthFace/NF0A2TCT_T5C_hero?$638x745$
# Completed Image ====> 1. nf0a2tct_t5c_hero?$638x745$.jpg
# Image URL: https://cdn.shopify.com/s/files/1/0936/7714/products/fleece-the-jump-pants-1.jpg?v=1518199756
# Completed Image ====> 2. fleece-the-jump-pants-1.jpg
# Image URL: https://www.duluthtrading.com/dw/image/v2/BBNM_PRD/on/demandware.static/-/Sites-dtc-master-catalog/default/dw14044f46/images/large/84505_BAR.jpg?sw=331&sh=331&sm=fit
# Completed Image ====> 3. 84505_bar.jpg
# Image URL: https://factory.jcrew.com/s7-img-facade/E6687_BR5646
# Completed Image ====> 4. e6687_br5646.jpg
# Image URL: https://assets.adidas.com/images/w_600,f_auto,q_auto/d5c4972c198a4435b6e9a6c9011b67e6_9366/Tiro_17_Training_Pants_Black_BS3685_21_model.jpg
# Completed Image ====> 5. tiro_17_training_pants_black_bs3685_21_model.jpg
# ...

# %%
arguments = {"output_directory":"category_dataset","keywords":"hoodie","limit":100,"print_urls":True}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
# Out:
# Item no.: 1 --> Item name = hoodie
# Evaluating...
# Starting Download...
# Image URL: https://cdn.shopify.com/s/files/1/0714/1079/products/Tanacon_Orange_Hoodie_Front_Mockup_2048x.jpg?v=1525287221
# Completed Image ====> 1. tanacon_orange_hoodie_front_mockup_2048x.jpg
# Image URL: https://mms-images.out.customink.com/mms/images/catalog/styles/295000/catalog_detail_image_large.jpg
# Completed Image ====> 2. catalog_detail_image_large.jpg
# Image URL: https://mms-images.out.customink.com/mms/images/catalog/styles/291900/catalog_detail_image_large.jpg
# Completed Image ====> 3. catalog_detail_image_large.jpg
# Image URL: https://cdn.shopify.com/s/files/1/0228/9021/products/SP7BlackLetterHoodieFlat_1024x1024.png?v=1521815565
# Completed Image ====> 4. sp7blackletterhoodieflat_1024x1024.png
# Image URL: https://images.thenorthface.com/is/image/TheNorthFace/NF0A3FR1_5KF_hero?$638x745$
# Completed Image ====> 5. nf0a3fr1_5kf_hero?$638x745$.jpg
# ...
